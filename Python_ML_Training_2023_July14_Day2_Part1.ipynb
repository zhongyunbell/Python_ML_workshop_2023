# %% [markdown]
# ## Pandas manipulation and ML example

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'https://artyudinsitemedia.nyc3.cdn.digitaloceanspaces.com/zomato.csv'
df = pd.read_csv(url, encoding='Latin1')

# %%
### Error about 'utf-8' seen
### Very frequent error, trick is to add "encoding='Latin1'"
### encoding default is usually "uft-8"

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# ### Encoding system

# %%
# python ord gives a number
ord("A") # ord means order, and gives a number for each character
# Out:
# 65

# %%
ord("a")
# Out:
# 97

# %%
# "utf-8": every character gets some number. Most popular encoding language
# A new number assigned

# %%
# How to deal with missing data
df.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# How many restaurants have the highest aggregate rating

max_rating = df['Aggregate rating'].max()
#df['Aggregate rating'].count()

df[df['Aggregate rating']==max_rating].count()[0]
# Out:
# 61

# %%
## Statistical snapshot of the column
df['Aggregate rating'].describe()
# Out:
# count    9542.000000
# mean        2.665238
# std         1.516588
# min         0.000000
# 25%         2.500000
# 50%         3.200000
# 75%         3.700000
# max         4.900000
# Name: Aggregate rating, dtype: float64

# %%
# Provide count of unique values, and sort by count
## Works on string/float/int

df['Aggregate rating'].value_counts()
# Out:
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     495
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     399
# 2.9     381
# 3.9     332
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     143
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      41
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: Aggregate rating, dtype: int64

# %%
## Use "True", and convert into percentages
df['Aggregate rating'].value_counts(True)
# Out:
# 0.0    0.225110
# 3.2    0.054706
# 3.1    0.054391
# 3.4    0.051876
# 3.3    0.050618
# 3.5    0.050304
# 3.0    0.049046
# 3.6    0.047998
# 3.7    0.044750
# 3.8    0.041815
# 2.9    0.039929
# 3.9    0.034794
# 2.8    0.033012
# 4.1    0.028715
# 4.0    0.027877
# 2.7    0.026200
# 4.2    0.023161
# 2.6    0.020017
# 4.3    0.018235
# 4.4    0.014986
# 2.5    0.011528
# 4.5    0.009956
# 2.4    0.009118
# 4.6    0.008174
# 4.9    0.006393
# 2.3    0.004926
# 4.7    0.004297
# 2.2    0.002830
# 4.8    0.002620
# 2.1    0.001572
# 2.0    0.000734
# 1.9    0.000210
# 1.8    0.000105
# Name: Aggregate rating, dtype: float64

# %%
df.head(3)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
# ...

# %%
## How many restaurants located in Abu Dhabi

df[df['City'].str.contains("Abu Dhabi", case=False)].count()[0]
# Out:
# 20

# %%
df['City'].value_counts()
# Out:
# New Delhi         5473
# Gurgaon           1118
# Noida             1080
# Faridabad          251
# Ghaziabad           25
#                   ...
# Lincoln              1
# Lakeview             1
# Lakes Entrance       1
# Inverloch            1
# Panchkula            1
# Name: City, Length: 140, dtype: int64

# %%
ad = 'Abu Dhabi'

## Need to use "@" in query
df.query('City == @ad').count()
# Out:
# Restaurant ID           20
# Restaurant Name         20
# Country Code            20
# City                    20
# Address                 20
# Locality                20
# Locality Verbose        20
# Longitude               20
# Latitude                20
# Cuisines                20
# Average Cost for two    20
# Currency                20
# Has Table booking       20
# Has Online delivery     20
# Is delivering now       20
# Switch to order menu    20
# Price range             20
# Aggregate rating        20
# Rating color            20
# Rating text             20
# Votes                   20
# dtype: int64

# %%
df.query("City == 'Abu Dhabi'").count()[0]
# Out:
# 20

# %%
# Returns as a series, with index and value, use index to grab values
df['City'].value_counts()['New Delhi']
# Out:
# 5473

# %%
## Get the restaurants with highest rating in New Delhi
df[df['City'] == 'New Delhi'].sort_values(by='Aggregate rating', ascending=False)
# Out:
#       Restaurant ID            Restaurant Name  Country Code       City  \
# 3013         310143         Naturals Ice Cream             1  New Delhi
# 3601           2004  Indian Accent - The Manor             1  New Delhi
# 4298       18345728             Masala Library             1  New Delhi
# 6656       18445790               Kopper Kadai             1  New Delhi
# 3012       18418277                MOB Brewpub             1  New Delhi
# ...             ...                        ...           ...        ...
# 5671       18471270             Chicken Darwar             1  New Delhi
# 5670         311394            Cheffron Bakery             1  New Delhi
# 5669       18432206       Captain Food Factory             1  New Delhi
# 5668         312620          Brown Town Bakers             1  New Delhi
# 8032       18212160       Zareen's Dastarkhwan             1  New Delhi
#
#                                                 Address         Locality  \
# ...

# %%
# Multiple conditions
cond1 = df["City"] =='Abu Dhabi'
cond2 = df["Aggregate rating"] == df["Aggregate rating"].max()
df[cond1 & cond2]['City']
# Out:
# 580    Abu Dhabi
# Name: City, dtype: object

# %%
# Use copy() to make "New Delhi" df a totally separate object
new_del = df[df["City"] == "New Delhi"].copy()
new_del["Aggregate rating"].max()
new_del[new_del['Aggregate rating']==new_del["Aggregate rating"].max()]
# Out:
#       Restaurant ID            Restaurant Name  Country Code       City  \
# 3013         310143         Naturals Ice Cream             1  New Delhi
# 3601           2004  Indian Accent - The Manor             1  New Delhi
# 4298       18345728             Masala Library             1  New Delhi
#
#                                             Address         Locality  \
# 3013  L-8, Outer Circle, Connaught Place, New Delhi  Connaught Place
# 3601       The Manor, 77, Friends Colony, New Delhi   Friends Colony
# 4298                       21 A, Janpath, New Delhi          Janpath
#
#                 Locality Verbose  Longitude   Latitude       Cuisines  ...  \
# 3013  Connaught Place, New Delhi  77.222148  28.634348      Ice Cream  ...
# 3601   Friends Colony, New Delhi  77.257106  28.570142  Modern Indian  ...
# 4298          Janpath, New Delhi  77.218645  28.618245  Modern Indian  ...
#
#                 Currency Has Table booking Has Online delivery  \
# ...

# %%
## Python use "&", vectorized condition

# %%
df["Cuisines"]
# Out:
# 0             French, Japanese, Desserts
# 1                               Japanese
# 2       Seafood, Asian, Filipino, Indian
# 3                        Japanese, Sushi
# 4                       Japanese, Korean
#                       ...
# 9546                             Turkish
# 9547     World Cuisine, Patisserie, Cafe
# 9548              Italian, World Cuisine
# 9549                     Restaurant Cafe
# 9550                                Cafe
# Name: Cuisines, Length: 9542, dtype: object

# %%
## Japanese food in multiple types of strings

# %%
df["Cuisines"].str.contains("Japanese", case=False).count()
# Out:
# 9542

# %%
# Split returns a list
df["New_Cuisines"] = df["Cuisines"].str.split(",")

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
## Function explode works only on a list
### Will create three record by splitting a list
### Duplicate records for each item in the list

# %%
cuisines = df.explode("New_Cuisines").copy()

# %%
cuisines["New_Cuisines"].value_counts()
# Out:
# North Indian      2992
#  Chinese          1880
#  Fast Food        1314
#  North Indian      968
# Chinese            855
#                   ...
#  Ramen               1
# Indonesian           1
#  Bubble Tea          1
# Kiwi                 1
#  World Cuisine       1
# Name: New_Cuisines, Length: 249, dtype: int64

# %%
cuisines["New_Cuisines"] = cuisines["New_Cuisines"].str.strip()

# %%
cuisines["New_Cuisines"].value_counts()['Japanese']
# Out:
# 135

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'New_Cuisines'],
#       dtype='object')

# %%
## What is the name and rating of the most expensive 
## restaurant for two ("Average Cost for two")

df[df['Average Cost for two']==df['Average Cost for two'].max()][['Restaurant Name', 'Aggregate rating']]
# Out:
#                Restaurant Name  Aggregate rating
# 9283                      Skye               4.1
# 9284  Satoo - Hotel Shangri-La               4.6

# %%
## Find most expensive Chinese restaurant in New Delhi 
## in US Dollars 1 Indian Rupee is 0.013 USD

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'New_Cuisines'],
#       dtype='object')

# %%
df_new_delhi = df[df['City']=='New Delhi']
df_new_delhi_Chinese = df_new_delhi[df_new_delhi["Cuisines"].str.contains("Chinese", case=False)]
df_new_del_CHN_highest = df_new_delhi_Chinese[df_new_delhi_Chinese['Average Cost for two']==df_new_delhi_Chinese['Average Cost for two'].max()]

# %%
df_new_del_CHN_highest
# Out:
#       Restaurant ID                           Restaurant Name  Country Code  \
# 4088         309548  Tian - Asian Cuisine Studio - ITC Maurya             1
#
#            City                                            Address  \
# 4088  New Delhi  ITC Maurya, Diplomatic Enclave, Chanakyapuri, ...
#
#                       Locality                     Locality Verbose  \
# 4088  ITC Maurya, Chanakyapuri  ITC Maurya, Chanakyapuri, New Delhi
#
#       Longitude   Latitude                                Cuisines  ...  \
# 4088  77.173455  28.597351  Asian, Japanese, Korean, Thai, Chinese  ...
#
#       Has Table booking Has Online delivery Is delivering now  \
# 4088                 No                  No                No
#
#      Switch to order menu Price range Aggregate rating  Rating color  \
# 4088                   No           4              4.1         Green
#
#       Rating text Votes                                  New_Cuisines
# ...

# %%
print(df_new_delhi.shape, df_new_delhi_Chinese.shape)
# Out:
# (5473, 22) (1638, 22)

# %%
# Solution
new_del["USD"] = new_del["Average Cost for two"]*0.013
new_del_chinese = new_del[new_del["Cuisines"].str.contains("Chinese", case=False)]
con_chi_nd = new_del_chinese['USD'] == new_del_chinese['USD'].max()
new_del_chinese[con_chi_nd]
# Out:
#       Restaurant ID                           Restaurant Name  Country Code  \
# 4088         309548  Tian - Asian Cuisine Studio - ITC Maurya             1
#
#            City                                            Address  \
# 4088  New Delhi  ITC Maurya, Diplomatic Enclave, Chanakyapuri, ...
#
#                       Locality                     Locality Verbose  \
# 4088  ITC Maurya, Chanakyapuri  ITC Maurya, Chanakyapuri, New Delhi
#
#       Longitude   Latitude                                Cuisines  ...  \
# 4088  77.173455  28.597351  Asian, Japanese, Korean, Thai, Chinese  ...
#
#       Has Table booking Has Online delivery Is delivering now  \
# 4088                 No                  No                No
#
#      Switch to order menu Price range Aggregate rating  Rating color  \
# 4088                   No           4              4.1         Green
#
#       Rating text Votes   USD
# 4088    Very Good   188  91.0
#
# [1 rows x 22 columns]

# %%
## Value counts
df["City"].value_counts()
# Out:
# New Delhi         5473
# Gurgaon           1118
# Noida             1080
# Faridabad          251
# Ghaziabad           25
#                   ...
# Lincoln              1
# Lakeview             1
# Lakes Entrance       1
# Inverloch            1
# Panchkula            1
# Name: City, Length: 140, dtype: int64

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
cities = df.groupby("City")[["Restaurant ID"]].count()
cities.sort_values(by="Restaurant ID", )
# Out:
#                  Restaurant ID
# City
# Abu Dhabi                   20
# Agra                        20
# Ahmedabad                   21
# Albany                      17
# Allahabad                   20
# ...                        ...
# Weirton                      1
# Wellington City             20
# Winchester Bay               1
# Yorkton                      1
# ÛÁstanbul                   14
#
# [140 rows x 1 columns]

# %%
## 2-D header
### City is index name, "City" is not a column here

# %%
cities.columns
# Out:
# Index(['Restaurant ID'], dtype='object')

# %%
## Could be multi index
cities.index
# Out:
# Index(['Abu Dhabi', 'Agra', 'Ahmedabad', 'Albany', 'Allahabad', 'Amritsar',
#        'Ankara', 'Armidale', 'Athens', 'Auckland',
#        ...
#        'Vernonia', 'Victor Harbor', 'Vineland Station', 'Vizag', 'Waterloo',
#        'Weirton', 'Wellington City', 'Winchester Bay', 'Yorkton', 'ÛÁstanbul'],
#       dtype='object', name='City', length=140)

# %%
cities = df.groupby(["City", "Aggregate rating"])[["Restaurant ID"]].count()

# %%
cities
# Out:
#                             Restaurant ID
# City      Aggregate rating
# Abu Dhabi 3.6                           1
#           4.0                           5
#           4.1                           1
#           4.2                           2
#           4.3                           2
# ...                                   ...
# ÛÁstanbul 4.2                           3
#           4.3                           1
#           4.5                           1
#           4.7                           2
#           4.9                           2
#
# [944 rows x 1 columns]

# %%
cities.columns
# Out:
# Index(['Restaurant ID'], dtype='object')

# %%
cities
# Out:
#                             Restaurant ID
# City      Aggregate rating
# Abu Dhabi 3.6                           1
#           4.0                           5
#           4.1                           1
#           4.2                           2
#           4.3                           2
# ...                                   ...
# ÛÁstanbul 4.2                           3
#           4.3                           1
#           4.5                           1
#           4.7                           2
#           4.9                           2
#
# [944 rows x 1 columns]

# %%
## Multi-index, hierachical index

# %%
cities.loc["New Delhi"].loc[0.0]
# Out:
# Restaurant ID    1425
# Name: 0.0, dtype: int64

# %%
cities.loc["New Delhi"]
# Out:
#                   Restaurant ID
# Aggregate rating
# 0.0                        1425
# 1.9                           2
# 2.0                           2
# 2.1                           8
# 2.2                          14
# 2.3                          25
# 2.4                          46
# 2.5                          64
# 2.6                         129
# 2.7                         170
# 2.8                         216
# 2.9                         253
# 3.0                         318
# 3.1                         358
# 3.2                         353
# 3.3                         332
# 3.4                         302
# 3.5                         286
# 3.6                         251
# 3.7                         231
# 3.8                         200
# 3.9                         160
# 4.0                          89
# 4.1                          84
# 4.2                          64
# 4.3                          32
# 4.4                          31
# ...

# %%
## Multi index
pd.MultiIndex.append

## Hierachical columns
# Out:
# <function pandas.core.indexes.multi.MultiIndex.append(self, other)>

# %%
cities = df.groupby(["City"])[["Restaurant ID"]].count()
cities.sort_values(by="Restaurant ID", ascending=False, inplace = True)

# %%
top_5 = cities[:5]

# %%
top_5
# Out:
#            Restaurant ID
# City
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25

# %%
type(top_5)
# Out:
# pandas.core.frame.DataFrame

# %%
top_5.reset_index(inplace=True)

# %%
x = top_5["Restaurant ID"]
labels = top_5["City"]
## provide values for explore
e = [0.5,0,0,0,0.5]
plt.figure(figsize=(10,10))
plt.pie(x, labels=labels, explode=e);
